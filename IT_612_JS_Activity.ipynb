# %% [markdown]
# <a href="https://colab.research.google.com/github/parkerherty/it612/blob/main/IT_612_JS_Activity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile code.js
# function addTax(price, rate) {
#   price = price * (1 + rate)
#   return price
# }
#
# function createBurner(secret, limit) {
#   for (let i = 0; i < limit; i++) {
#     console.log(secret)
#   }
# }
#
# let limit = createBurner(5)
# console.log(limit("secret"))
# let price = addTax(100, 0.08)
# Out:
# Overwriting code.js

# %%
# !node code.js
# Out:
# /content/code.js:13
# console.log(limit("secret"))
#             ^
#
# TypeError: limit is not a function
#     at Object.<anonymous> (/content/code.js:13:13)
#     at Module._compile (node:internal/modules/cjs/loader:1529:14)
#     at Module._extensions..js (node:internal/modules/cjs/loader:1613:10)
#     at Module.load (node:internal/modules/cjs/loader:1275:32)
#     at Module._load (node:internal/modules/cjs/loader:1096:12)
#     at Function.executeUserEntryPoint [as runMain] (node:internal/modules/run_main:164:12)
#     at node:internal/main/run_main_module:28:49
#
# Node.js v20.19.0
